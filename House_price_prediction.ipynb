# %% [markdown]
# <a href="https://colab.research.google.com/github/DRN1999/Mumbai_House_price_prediction/blob/main/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/house_price.csv')
df.head()
# Out:
#    price_cr  area_in_sqft apartment parking location_mumbai
# 0      0.50           300       1RK       B             NWM
# 1      0.56           300       1RK       B             NWM
# 2      0.65           355       1RK      No             NWM
# 3      0.95           430      1BHK       B             NWM
# 4      0.80           480       1RK       C             NWM

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df['apartment'] = label.fit_transform(df['apartment'])

# %%
df['parking']=label.fit_transform(df['parking'])

# %%
df['location_mumbai']=label.fit_transform(df['location_mumbai'])
df.head()
# Out:
#    price_cr  area_in_sqft  apartment  parking  location_mumbai
# 0      0.50           300          1        0                1
# 1      0.56           300          1        0                1
# 2      0.65           355          1        3                1
# 3      0.95           430          0        0                1
# 4      0.80           480          1        2                1

# %%
x = df.iloc[:,1:5]

# %%
y = df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
x_test.shape
# Out:
# (13, 4)

# %%
y_test.shape
# Out:
# (13,)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
pricemodel = RandomForestRegressor()

# %%
pricemodel.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
x_test
# Out:
#     area_in_sqft  apartment  parking  location_mumbai
# 2            355          1        3                1
# 6            490          0        1                1
# 47          7500          5        2                2
# 40          1400          3        1                0
# 46          6000          5        2                3
# 9            559          0        1                1
# 17           601          0        1                0
# 5            486          0        0                1
# 41          1490          3        1                1
# 20           650          2        1                1
# 15           591          0        3                2
# 22           660          0        0                1
# 21           650          2        2                0

# %%
y_pred=pricemodel.predict(x_test)
print(y_pred)
y_test
# Out:
# [ 0.62502   0.8989   47.6398    4.4054   46.4595    1.0248    1.240715
#   0.8648    4.1862    1.5746    1.196145  1.2896    1.65859 ]
# 2      0.65
# 6      0.53
# 47    30.00
# 40     3.15
# 46    45.00
# 9      1.07
# 17     0.82
# 5      0.85
# 41     3.00
# 20     1.05
# 15     2.25
# 22     0.86
# 21     1.15
# Name: price_cr, dtype: float64

# %%
from sklearn.metrics import mean_absolute_percentage_error
print('testing score:',pricemodel.score(x_test, y_test)*100)
print('Actual op vs pred op:',mean_absolute_percentage_error(y_test, y_pred))
print('training score:',pricemodel.score(x_train, y_train)*100)
# Out:
# testing score: 86.31650716452343
# Actual op vs pred op: 0.356257137543847
# training score: 97.99445507809173

# %%
import csv
import time
def price():
  area_in_sqft = int(input("Area_in_sqft: "))
  bhk = (input("Bedroom: "))
  parking = (input("parking: "))
  location_mumbai = (input("Location_mumbai: "))
  listhouse = [area_in_sqft, bhk, parking, location_mumbai]
  print(listhouse)
  bhk= int(bhk.replace('1BHK', '0').replace('1RK', '1').replace('2BHK', '2').replace('3BHK', '3').replace('4BHK', '4').replace('5BHK', '5'))
  parking = int(parking.replace('B', '0').replace('BC', '1').replace('C', '2').replace('No', '3'))
  location_mumbai = int(location_mumbai.replace('NEM', '0').replace('NWM', '1').replace('SEM', '2').replace('SWM', '3'))
  '''if furnishingstatus == 'furnished':
    furnishingstatus = 0
  elif furnishingstatus == 'semi-furnished':
    furnishingstatus = 1
  else:
    furnishingstatus= 2'''


  #furnishingstatus= int(furnishingstatus.replace('furnished', '0').replace('semi-furnished', '1').replace('unfurnished','2'))
  listhouse1 = [area_in_sqft, bhk, parking, location_mumbai]
  print(listhouse1)
  price= pricemodel.predict([listhouse1])
  printed_price = price[0]
  entry_price = round(printed_price, 2)
  print(entry_price)
  #sleeping time
  time.sleep(20)
  dataset = [{'price_cr': entry_price, 'area_in_sqft':listhouse[0], 'apartment':listhouse[1], 'parking':listhouse[2], 'location_mumbai':listhouse[3]}]
  isitright = input("Feedback: ")
  if isitright == 'yes':
    with open('/content/sample_data/house_price.csv', mode = 'a', newline='')as file:
      writer = csv.writer(file)
      for row in dataset:
        writer.writerow([row['price_cr'], row['area_in_sqft'], row['apartment'], row['parking'], row['location_mumbai']])
      file.close()
  else:
    print(price)

# %%
price()
# Out:
# Area_in_sqft: 400
# Bedroom: 1BHK
# parking: B
# Location_mumbai: NEM
# [400, '1BHK', 'B', 'NEM']
# [400, 0, 0, 0]
# [0.870895]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Feedback: No
# [0.870895]

# %%
price()
# Out:
# Area_in_sqft: 1500
# Bedroom: 3BHK
# parking: BC
# Location_mumbai: SWM
# [1500, '3BHK', 'BC', 'SWM']
# [1500, 3, 2, 3]
# [7.5094]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Feedback: Yes
# [7.5094]

# %%
price()
# Out:
# Area_in_sqft: 1500
# Bedroom: 3BHK
# parking: BC
# Location_mumbai: SWM
# [1500, '3BHK', 'BC', 'SWM']
# [1500, 3, 2, 3]
# 7.51
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Feedback: yes
